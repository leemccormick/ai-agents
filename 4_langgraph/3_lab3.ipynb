# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %% [markdown]
# ### First - a heads up for Windows PC users
#
# While executing this notebook, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky!
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out that line of code in that file! And save the file.
# 5. Restart the kernel by pressing the "Restart" button above
#
# Thank you to student Nicolas for finding this, and to Yaki, Zibin and Bhaskar for confirming that this worked for them!

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ### Next: Install Playwright
#
# On Windows and MacOS:
# `playwright install`
#
# On Linux:
# `playwright install —with-reps chromium`

# %% [markdown]
# ### Introducing nest_asyncio
#
# Python async code only allows for one "event loop" processing aynchronous events.
#
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/leemccormick/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# Job Corps ends Live: Expert economic analysis Bryan Mena Writer, CNN
# Business 2:23 PM EDT There's certainly been chatter among Fed
# reporters about Trump's comments today on Powell. Phil Mattingly Chief
# Domestic Correspondent and Anchor 2:22 PM EDT Moving to my second
# long-standing fixation: the Fed's concern about stagflation. Powell
# and colleagues have been increasingly concerned about the possibility
# - with a level of candor that actually surprised me last month. These
# economic projections directionally imply moves in that direction. But
# the June statement language tied to concern moderated a bit. Richard
# Quest CNN Business editor-at-large 2:19 PM EDT I think the core
# question comes down to: does the Fed feel the need to take out some
# insurance against stagflation? On today’s statement and reading the
# answer is no. Phil Mattingly Chief Domestic Correspondent and Anchor
# 2:16 PM EDT I promise I'll drop it after this, but the uncertainty
# piece of this has to be a huge focus in Powell's presser. He had to
# have set some unofficial record in his last presser for how many ways
# he said Fed officials had no clue what the future looked like. Now
# there's an escalating conflict between Iran-Israel and the full force
# of Trump's deportation action has also kicked into gear. And, yeah,
# tariffs/deals/deadlines. Interesting. Alicia Wallace Senior Economy
# Writer 2:14 PM EDT A couple of days ago, the University of Michigan
# noted a bump up in sentiment among consumers it surveyed. That being
# said, it's a leap upward after sentiment was languishing at the
# second-lowest reading on record (since 1952). Richard Quest CNN
# Business editor-at-large 2:13 PM EDT The president is going to be
# splenetic at this decision. The fact they are saying things are less
# uncertain but still refusing to do anything about it will be grist to
# his mill that they are acting quasi-politically -- which is not the
# case. Elisabeth Buchwald Economics Reporter 2:13 PM EDT Also just to
# note, Fed officials all sign off on the statement that's put out. They
# obsess over the language because they know even a seemingly subtle
# change of a word from last meeting can cause major market moves. Lucy
# Bayly Senior Economy Editor 2:13 PM EDT Today's presser could help
# shape investor sentiment as traders learn more about the Fed's
# thinking. Richard Quest CNN Business editor-at-large 2:12 PM EDT The
# wonderful part about trying to interpret the Fed is it’s watching
# grass grow and then suddenly realise the lawn is there. See all 0
# unread Fed holds interest rates steady again Show all Play Jerome
# Powell holds news conference after Federal Reserve’s interest rate
# decision - Source: CNN Live Updates Trump has been pushing the central
# bank to cut rates, but officials resist for the fourth straight
# meeting DOW 42,336.86 +121.06 0.29% S&P 500 6,000.26 +17.54 0.29%
# NASDAQ 19,599.55 +78.46 0.40% Supreme Court Kevin Dietsch/Getty Images
# SCOTUS issues blockbuster ruling on gender care for trans minors
# American toy companies bring Trump’s tariffs to the Supreme Court
# Jackson, Sotomayor and Gorsuch report earning huge sums for books For
# Subscribers Tracking the major Supreme Court cases of 2025 More top
# stories Heat will increase in the United States this week ahead of an
# even more brutal heat wave to come for parts of the country next week.
# CNN Weather A potent heat dome will send temperatures into the triple
# digits Social Security won’t be able to pay full benefits in 2034 if
# Congress doesn’t act Analysis And the federal employee of the year is…
# someone who quit in protest Potential witness in Bryan Kohberger case
# appears to say she saw him at the scene, police video shows Video
# Watch singer perform National Anthem in Spanish after she says Dodgers
# staff objected 1:35 Video Tucker Carlson confronts Ted Cruz about Iran
# 1:17 Fox News takes pro-war position as MAGA media feuds over Israel-
# Iran conflict When kids use screens, parents worry about the wrong
# thing, new study suggests The Motley Fool Hands down one of the best
# cards for good credit Minnesota shootings Stephen Maturen/Getty Images
# Police investigate apparent break-in at slain Minnesota lawmaker’s
# home Officer’s gut feeling stopped suspect from reaching other
# targets, police say Video Trump tells CNN reporter why he won’t be
# calling Minnesota governor after shootings 0:27 Environment Trash as
# high as seven to eight floors found in a cave in Zhangjiajie City,
# Hunan Province, China @Xiaofugege Viral videos prompt mass cleanup of
# caves near China’s famed ‘Avatar’ mountains Highly microplastic-
# polluted US coastal waters linked to serious health risks, study finds
# Ad Feedback Ad Feedback CNN UNDERSCORED Joe Bloss/CNN Underscored The
# best car emergency kits that every driver should have in their vehicle
# Apr 28, 2025 Suzanne Kattau/CNN Underscored I cut my junk mail down to
# find the best paper shredders. Here are the 2 you want May 24, 2025
# Maxwell Shukuya/CNN Underscored I’ve been ordering from Backcountry
# for a decade. Here are my discounted summer faves Jun 17, 2025 Ad
# Feedback Sports spotlight Mark J. Rebilas/USA TODAY Sports/Reuters
# Former NFL player apologizes to family of woman he killed in fatal DUI
# crash Minor League Baseball/X Luis Guevara, 19-year-old Baltimore
# Orioles minor league player, dies following jet ski crash Trevor
# Ruszkowski/Imagn Images/Reuters Is the WNBA doing enough to protect
# Caitlin Clark after Indiana Fever star is jabbed in eye and bumped to
# floor? Check these out • Look of the Week Look of the Week From Ryan
# Murphy Productions Look of the Week Carolyn Bessette Kennedy and the
# dangers of dressing an icon • Video 3:24 CNN Video These homes were
# made in a factory. They could be the future of net-zero construction
# 3:24 Anton Dobrea/iStockphoto/Getty Images 24 of the world’s best
# salads Hebei GEO University ‘Dragon Man’ DNA revelation puts a face to
# a mysterious group of ancient humans For Subscribers • For Subscribers
# For Subscribers Maddie McGarvey for CNN For Subscribers A new kind of
# doomsday prepper emerged during Trump’s rise to power • For
# Subscribers For Subscribers Nikos Frazier/Omaha World-Herald/AP For
# Subscribers The ICE raid in Nebraska that shocked officials and split
# families • For Subscribers For Subscribers Cedar Attanasio/AP For
# Subscribers ‘We didn’t see the daylight’: Migrant families describe
# prolonged detention in border facilities Ad Feedback Ad Feedback CNN
# Underscored Best-in-class Rachel Dennis/CNN Underscored The 10 best
# Walmart deals to shop this week: Stasher, Crocs, Ninja and more The
# internet loves Halara, so we tested its viral clothes to see if
# they’re actually worth adding to cart You need a good portable
# charger. Luckily, we found 3 that are worth your money 10 of our
# editors’ favorite cooling beauty products for instant heat relief
# Amazon just announced Prime Day. These are the dates and the best
# early deals Expert-backed guides Show all Kai Burkhardt/CNN
# Underscored I tested 12 pairs of hiking sandals. These 2 were
# comfortable, grippy and supportive Prime Day is coming, but these
# great Nintendo Switch deals are live now We asked 6 expert gardeners
# to share their favorite gardening tools. Here’s what they recommend
# Sunglasses don’t need to be expensive to be high-quality. So we found
# 16 of the best ones Mosquitoes don’t stand a chance this summer with
# this repeller that actually works Editors' picks Joe Bloss/CNN
# Underscored My car doesn’t have GPS, so I tested the best car phone
# holders to modernize my ride The 10 best We Made Too Much scores
# Forget the expensive air conditioner. Try one of these powerful
# cooling fans instead We tested 12 nonstick pans. Only 2 are worth
# buying Chase Sapphire Reserve is making big changes, including a $795
# annual price hike US Show all Justin Sullivan/Getty Images Waymo is
# returning to NYC, but it still needs a change in the law to provide
# driverless rides Chicken fettuccine Alfredo meals sold at Kroger and
# Walmart recalled after illnesses, deaths from listeria Prosecutors set
# to present evidence against man charged with hate crime in Boulder
# attack How cities are scaling back Juneteenth celebrations
# Entertainment Show all Kevork Djansezian/Getty Images Singer Nezza
# explains why she sang US National Anthem in Spanish at Dodgers game;
# says team objected Ariana Grande shares that her grandmother Marjorie
# ‘Nonna’ Grande has died Beyoncé pays tribute to both Paul McCartney
# and Stella McCartney for ‘Blackbird’ inspiration Ad Feedback PAID
# PARTNER CONTENT Thousands rush to 0% APR cards lasting until 2027
# CardCritics Stop Paying Interest: 18 Months of 0% APR Awaits
# CardCritics Space and Science Show all Shana Goffredi First methane-
# powered sea spiders found crawling on the ocean floor A long-standing
# puzzle of ‘missing’ ordinary matter in the universe may be solved,
# astronomers say 14,000-year-old mummified ‘puppies’ weren’t dogs at
# all, new research shows Reopening a 688-year-old murder case reveals a
# web of adultery and extortion in medieval England Travel Show all
# Volha Shukaila/SOPA Images/LightRocket/Getty Images World’s most
# liveable city for 2025 revealed Museum’s CCTV shows moment visitor
# broke artwork by sitting on it These chefs and restaurants are the
# 2025 James Beard Award winners The unwritten rules of visiting a
# British pub Style Show all • Video 2:57 TPS Productions/Focus Features
# Video Why the suits worn in Wes Anderson's latest film have a deeper
# meaning 2:57 Remember when Princess Diana wowed the Met Gala in a
# risqué — and secretly altered — gown? Video 70 years ago, this moment
# cemented Marilyn Monroe’s legacy as a Hollywood goddess 2:06 Remember
# when Liz Hurley wore ‘that’ dress? health and wellness juanma
# hache/Moment RF/Getty Images Marijuana use dramatically increases risk
# of dying from heart attacks and stroke, large study finds Video
# Tatted, hard-rock therapist Dr. John Delony looks tough, but his
# advice for dads is straight from the heart 1:32 A father’s poor mental
# health may harm his children’s development, study finds Walking more
# may prevent the leading cause of disability in the US, study says More
# Politics Show all • Analysis Analysis Spencer Platt/Getty Images/File
# Analysis Obama’s awkward call for a broad-scale Trump resistance CNN
# Exclusive Noem demands more control over FEMA and Homeland Security
# funding, which could slow disaster response Ghazala Hashmi wins
# Democratic nomination for Virginia lieutenant governor Trump will
# grant TikTok another extension in enforcement of sale-or-ban law
# Analysis Trump may be on the brink of a huge gamble Business Show all
# Adrees Latif/Reuters What’s open and closed on Juneteenth 2025 Texas
# Instruments to invest more than $60 billion to make semiconductors in
# the US Liquid Death’s next act: A whiskey aged in a casket Amazon says
# it will reduce its workforce as AI replaces human employees World
# Show all Max Mumby/Indigo/Getty Images Princess of Wales pulls out of
# Royal Ascot British lawmakers vote to decriminalize abortion for
# pregnant women while America cracks down While North Korea denied
# Covid-19 cases, the virus was widespread and barely treated, report
# says India and Canada signal a reset of relations nearly two years
# after assassination of Sikh separatist Indonesia volcano spews ash
# more than 6 miles into sky, dozens of Bali flights canceled CNN
# podcasts Show all Itay Cohen/Reuters The civilian cost of Israel and
# Iran’s conflict What happened to juror No. 6? Digg’s founder on making
# social media more human again How AI might be helping your doctor
# treat you ‘It’s don’t ask, don’t tell 2.0.’: Trump’s Trans service
# member ban Sports Show all Photos: Stanley Cup dented in celebration
# Red Sox used AI bot for front office interviews Rays In ‘advanced
# talks’ to sell team at $1.7B valuation After another playoff
# disappointment, what’s next for Connor McDavid? Winners and losers
# from the Stanley Cup Final Video • Video 1:35 TikTok@babynezza, CNN
# Video Watch singer perform National Anthem in Spanish after she says
# Dodgers staff objected 1:35 • Video 3:31 AARON CHERRIE PHOTOGRAPHY
# Video Photographer captures the Milky Way in one of the UK’s darkest
# places 3:31 • Video 2:38 BBC Video How Colin Firth’s wet shirt in
# BBC’s ‘Pride and Prejudice’ sparked Austen-mania 2:38 • Video 1:32
# Lacey Russell/CNN Video Tatted, hard-rock therapist Dr. John Delony
# looks tough, but his advice for dads is straight from the heart 1:32
# Food and Home Buff Strickland / Food Network The 5 best summer
# appetizers Food Network How to grill corn on the cob with and without
# husks BaileyNurseries.com What you should be pruning in early summer
# Paid Content Paid Content Recommendations More from CNN Art and Style
# Noemi Cassanelli/CNN This artist is keeping Hong Kong’s neon heritage
# alive Christopher Polk/Penske Media/Getty Images Look of the Week:
# Rebecca Black dresses for a shotgun wedding at the AMAs in Vegas
# Remember When Stephane Cardinale/Corbis/Sygma/Getty Images Remember
# when Princess Diana wowed the Met Gala in a risqué — and secretly
# altered — gown? • Video 3:11 Mike Coppola/Getty Images North
# America/Getty Images Video Why these Met Gala moments stand out in
# history 3:11 Ad Feedback Photos Giles Clarke What life is like in
# Sudan, where a devastating crisis has changed lives forever Rebecca
# Noble for CNN As a gay teen, his dad didn’t support him. Now the pair
# are bringing drag shows to rural towns • Gallery Gallery David
# Swanson/Reuters Gallery The week in 38 photos • Gallery Gallery Phil
# Mccarten/UPI/Shutterstock Gallery Remembering Beach Boys co-founder
# Brian Wilson Paid Partner Content CNN Games + Quizzes Show all •
# Today's crossword Today's crossword CNN Today's crossword No pencil or
# eraser required • Sudoblock Sudoblock CNN Sudoblock Sudoku + Blocks =
# addictive tile-matching puzzle • Jumble Crossword Jumble Crossword CNN
# Jumble Crossword Test your smarts with this scrambled word game •
# Weekly news quiz Weekly news quiz cnn Weekly news quiz What do you
# remember from the week that was? In case you missed it Charlie
# Riedel/AP ‘Like everyone on the planet giving up breakfast’: Calories
# from food production set to plummet as the world heats up Louvre
# museum shuts its doors as staff say they are overwhelmed Emma
# Raducanu’s accused stalker prevented from buying Wimbledon tickets
# Elderly man drives down Rome’s Spanish Steps and gets stuck
# Photographer is on a mission to define his country’s ‘architectural
# identity’ Florida Panthers win second straight Stanley Cup Museum’s
# CCTV shows moment visitor broke artwork by sitting on it Supreme Court
# declines to hear copyright appeal that alleged Ed Sheeran copied
# Marvin Gaye song A long-standing puzzle of ‘missing’ ordinary matter
# in the universe may be solved, astronomers say Lewis Hamilton ‘so sad’
# after hitting groundhog during Canadian Grand Prix as George Russell
# claims win Despite two months of tariffs, car prices aren’t going up.
# Is now the time to buy? Subscribe Sign in My Account Settings
# Newsletters Topics you follow Sign out Your CNN account Sign in to
# your CNN account Live TV Listen Watch US Crime + Justice World Africa
# Americas Asia Australia China Europe India Middle East United Kingdom
# Politics Trump Facts First CNN Polls 2025 Elections Business Tech
# Media Calculators Videos Markets Pre-markets After-Hours Fear & Greed
# Investing Markets Now Nightcap Health Life, But Better Fitness Food
# Sleep Mindfulness Relationships Entertainment Movies Television
# Celebrity Tech Innovate Foreseeable Future Mission: Ahead Work
# Transformed Innovative Cities Style Arts Design Fashion Architecture
# Luxury Beauty Video Travel Destinations Food & Drink Stay News Videos
# Sports Pro Football College Football Basketball Baseball Soccer
# Olympics Hockey Science Space Life Unearthed Climate Solutions Weather
# Weather Video Climate Ukraine-Russia War Israel-Hamas War Watch Live
# TV CNN Headlines CNN Shorts Shows A-Z CNN10 CNN Max CNN TV Schedules
# FlashDocs Listen CNN 5 Things Chasing Life with Dr. Sanjay Gupta The
# Assignment with Audie Cornish One Thing Tug of War CNN Political
# Briefing The Axe Files All There Is with Anderson Cooper All CNN Audio
# podcasts CNN Underscored Electronics Fashion Beauty Health & Fitness
# Home Reviews Deals Gifts Travel Outdoors Pets Games Daily Crossword
# Jumble Crossword Sudoblock Sudoku 5 Things Quiz About CNN Subscribe
# Photos Investigations CNN Profiles CNN Leadership CNN Newsletters Work
# for CNN Watch Listen Live TV Follow CNN Subscribe Sign in My Account
# Settings Newsletters Topics you follow Sign out Your CNN account Sign
# in to your CNN account Terms of Use Privacy Policy Cookie Settings Ad
# Choices Accessibility & CC About Subscribe Newsletters Transcripts
# Help Center © 2025 Cable News Network. A Warner Bros. Discovery
# Company. All Rights Reserved. CNN Sans ™ & © 2016 Cable News Network.
# Privacy Policy For privacy options, please see our privacy policy:
# https://www.cnn.com/privacy . Back Button Cookie List Search Icon
# Filter Icon Clear checkbox label label Apply Cancel Consent
# Leg.Interest checkbox label label checkbox label label checkbox label
# label Close

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
